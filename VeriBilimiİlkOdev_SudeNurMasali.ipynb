# %% [markdown]
# <a href="https://colab.research.google.com/github/sudemasali/Car_Gallery_Management_System/blob/main/VeriBilimi%C4%B0lkOdev_SudeNurMasali.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# 1. 1.	Veri setini yükleyin ve ilk 10 satırı ile son 10 satırını ekrana yazdırın.
df = pd.read_csv("e_ticaret_veri_seti.csv")
df.head(10)
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100837    MUS1347  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2  SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri         İç Anadolu
# 3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 5  SIP100687    MUS1147  2025-08-09 08:42:00      Konya         İç Anadolu
# 6  SIP101351    MUS1011  2025-02-27 11:35:00   İstanbul            Marmara
# 7  SIP101172    MUS1357  2024-07-22 13:26:00     Ankara         İç Anadolu
# 8  SIP100779    MUS1354  2025-12-05 11:19:00   İstanbul            Marmara
# 9  SIP100202    MUS1067  2024-05-11 22:53:00      Bursa            Marmara
#
#      kategori              urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik          Nemlendirici     1       414.51           0.05
# ...

# %%
df.tail(10)
# Out:
#      siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 1418  SIP100056    MUS1238  2024-04-19 20:27:00     Ankara         İç Anadolu
# 1419  SIP101279    MUS1149  2024-08-24 08:38:00     Ankara         İç Anadolu
# 1420  SIP100920    MUS1425  2025-07-04 14:58:00      İzmir                Ege
# 1421  SIP100480    MUS1323  2024-06-20 20:34:00     Ankara         İç Anadolu
# 1422  SIP101222    MUS1440  2025-05-14 09:21:00      Bursa            Marmara
# 1423  SIP101093    MUS1187  2024-06-08 20:42:00   İstanbul            Marmara
# 1424  SIP101193    MUS1297  2025-11-06 08:17:00  Gaziantep  Güneydoğu Anadolu
# 1425  SIP101210    MUS1122  2025-03-07 09:07:00        NaN            Marmara
# 1426  SIP101060    MUS1189  2025-04-19 21:52:00    Kocaeli            Marmara
# 1427  SIP100642    MUS1289  2024-09-22 16:36:00     Ankara         İç Anadolu
#
#          kategori           urun_adi  adet  birim_fiyat  indirim_orani  \
# ...

# %%
# 2.Veri setinin satır sayısını, sütun sayısını ve tüm sütun isimlerini ekrana yazdırın.
satir_sayisi=df.shape[0]
satir_sayisi
# Out:
# 1428

# %%
sutun_sayisi=df.shape[1]
sutun_sayisi
# Out:
# 18

# %%
df.columns.tolist()
# Out:
# ['siparis_id',
#  'musteri_id',
#  'siparis_tarihi',
#  'sehir',
#  'bolge',
#  'kategori',
#  'urun_adi',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'odeme_turu',
#  'musteri_tipi',
#  'teslimat_gunu',
#  'musteri_puani',
#  'iade_durumu',
#  'kar_marji_orani',
#  'toplam_tutar']

# %%
# 3. info() ve describe() çıktılarını alın.
# Ardından veri setindeki sayısal sütunları ve kategorik sütunları ayrı ayrı listeleyin.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   siparis_id       1428 non-null   object
#  1   musteri_id       1428 non-null   object
#  2   siparis_tarihi   1428 non-null   object
#  3   sehir            1403 non-null   object
#  4   bolge            1428 non-null   object
#  5   kategori         1428 non-null   object
#  6   urun_adi         1428 non-null   object
#  7   adet             1428 non-null   int64
#  8   birim_fiyat      1428 non-null   float64
#  9   indirim_orani    1412 non-null   float64
#  10  kargo_ucreti     1428 non-null   float64
#  11  odeme_turu       1393 non-null   object
#  12  musteri_tipi     1386 non-null   object
#  13  teslimat_gunu    1400 non-null   float64
#  14  musteri_puani    1372 non-null   float64
#  15  iade_durumu      1428 non-null   object
# ...

# %%
df.describe()
# Out:
#               adet   birim_fiyat  indirim_orani  kargo_ucreti  teslimat_gunu  \
# count  1428.000000   1428.000000    1412.000000   1428.000000    1400.000000
# mean      2.136555    658.477654       0.052054     39.725140       3.370714
# std       2.015770   1042.414639       0.060115     14.185017       1.825990
# min       1.000000     93.110000       0.000000      0.000000       1.000000
# 25%       1.000000    199.185000       0.000000     29.900000       2.000000
# 50%       2.000000    287.120000       0.050000     39.900000       3.000000
# 75%       3.000000    819.177500       0.100000     49.900000       4.000000
# max      38.000000  18145.230000       0.200000     59.900000      31.000000
#
#        musteri_puani  kar_marji_orani  toplam_tutar
# count    1372.000000      1428.000000   1428.000000
# mean        4.002187         0.302799   1370.590336
# std         1.096707         0.069795   2961.689500
# min         0.000000         0.180000     89.680000
# ...

# %%
sayisal_sutunlar=df.select_dtypes(include= ["int64","float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar']

# %%
kategorik_sutunlar=df.select_dtypes(include=["object"]).columns.tolist()
kategorik_sutunlar
# Out:
# ['siparis_id',
#  'musteri_id',
#  'siparis_tarihi',
#  'sehir',
#  'bolge',
#  'kategori',
#  'urun_adi',
#  'odeme_turu',
#  'musteri_tipi',
#  'iade_durumu']

# %%
# 4.Her sütundaki eksik değer sayısını hesaplayın.
#Sonra eksik veri oranlarını yüzde olarak çıkarın ve eksik veri oranı en yüksek 5 sütunu yazdırın.
df.isnull().sum()
# Out:
# siparis_id          0
# musteri_id          0
# siparis_tarihi      0
# sehir              25
# bolge               0
# kategori            0
# urun_adi            0
# adet                0
# birim_fiyat         0
# indirim_orani      16
# kargo_ucreti        0
# odeme_turu         35
# musteri_tipi       42
# teslimat_gunu      28
# musteri_puani      56
# iade_durumu         0
# kar_marji_orani     0
# toplam_tutar        0
# dtype: int64

# %%
eksik_veri_sayilari=df.isnull().sum()
eksik_veri_oranlari=(eksik_veri_sayilari/len(df))*100
eksik_veri_oranlari
# Out:
# siparis_id         0.000000
# musteri_id         0.000000
# siparis_tarihi     0.000000
# sehir              1.750700
# bolge              0.000000
# kategori           0.000000
# urun_adi           0.000000
# adet               0.000000
# birim_fiyat        0.000000
# indirim_orani      1.120448
# kargo_ucreti       0.000000
# odeme_turu         2.450980
# musteri_tipi       2.941176
# teslimat_gunu      1.960784
# musteri_puani      3.921569
# iade_durumu        0.000000
# kar_marji_orani    0.000000
# toplam_tutar       0.000000
# dtype: float64

# %%
eksik_veri_oranlari.sort_values(ascending=False).head(5)
# Out:
# musteri_puani    3.921569
# musteri_tipi     2.941176
# odeme_turu       2.450980
# teslimat_gunu    1.960784
# sehir            1.750700
# dtype: float64

# %%
#5.	En az bir eksik değer içeren satırları filtreleyin ve bu satırlardan ilk 20 tanesini ekrana yazdırın.
eksik_veri_satirlari=df[df.isnull().any(axis=1)]
eksik_veri_satirlari.head(20)
# Out:
#     siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 19   SIP100677    MUS1148  2024-07-11 16:24:00      Adana            Akdeniz
# 33   SIP101126    MUS1406  2024-09-11 20:05:00     Mersin            Akdeniz
# 50   SIP101040    MUS1386  2025-04-01 09:30:00    Trabzon          Karadeniz
# 60   SIP100890    MUS1271  2024-11-07 19:47:00      İzmir                Ege
# 61   SIP101317    MUS1060  2024-09-05 20:49:00        NaN            Akdeniz
# 70   SIP100715    MUS1033  2024-11-10 21:50:00   İstanbul            Marmara
# 82   SIP100807    MUS1431  2025-01-07 14:12:00     Ankara         İç Anadolu
# 84   SIP100679    MUS1310  2024-05-20 18:51:00      İzmir                Ege
# 86   SIP101071    MUS1131  2024-09-18 12:24:00        NaN         İç Anadolu
# 92   SIP101366    MUS1347  2025-03-04 14:00:00      Bursa            Marmara
# 96   SIP101067    MUS1337  2025-06-02 12:23:00  Gaziantep  Güneydoğu Anadolu
# ...

# %%
#  6.indirim_orani ve musteri_puani sütunlarındaki eksik değerleri medyan ile doldurun.
#  Doldurmadan önce ve sonra bu iki sütundaki eksik değer sayılarını karşılaştırın.

indirim_orani_eksik_deger_sayisi = df['indirim_orani'].isnull().sum()
indirim_orani_eksik_deger_sayisi
# Out:
# np.int64(16)

# %%
musteri_puani_eksik_deger_sayisi=df["musteri_puani"].isnull().sum()
musteri_puani_eksik_deger_sayisi
# Out:
# np.int64(56)

# %%
df["indirim_orani"]=df["indirim_orani"].fillna(df["indirim_orani"].median)
df["musteri_puani"]=df["musteri_puani"].fillna(df["musteri_puani"].median)

# %%
indirim_orani_eksik_deger_sayisi=df["indirim_orani"].isnull().sum()
indirim_orani_eksik_deger_sayisi
# Out:
# np.int64(0)

# %%
musteri_puani_eksik_deger_sayisi=df["musteri_puani"].isnull().sum()
musteri_puani_eksik_deger_sayisi
# Out:
# np.int64(0)

# %%
# 7.	odeme_turu ve musteri_tipi sütunlarındaki eksik değerleri mod ile doldurun.
# Daha sonra bu sütunlarda eksik değer kalıp kalmadığını kontrol edin.
df["odeme_turu"]=df["odeme_turu"].fillna(df["odeme_turu"].mode)
odeme_turu_eksik_deger_sayisi=df["odeme_turu"].isnull().sum()
odeme_turu_eksik_deger_sayisi
# Out:
# np.int64(0)

# %%
df["musteri_tipi"]=df["musteri_tipi"].fillna(df["musteri_tipi"].mode)
musteri_tipi_eksik_deger_sayisi=df["musteri_tipi"].isnull().sum()
musteri_tipi_eksik_deger_sayisi
# Out:
# np.int64(0)

# %%
# 8.siparis_tarihi sütununu datetime tipine dönüştürün.
#Ardından bu sütundan siparis_yili, siparis_ayi, siparis_gunu ve haftanin_gunu adında 4 yeni sütun üretin ve ilk 10 satırını gösterin.
df["siparis_tarihi"]=pd.to_datetime(df["siparis_tarihi"])
df["siparis_tarihi"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["siparis_yili"]=df["siparis_tarihi"].dt.year
df["siparis_ayi"]=df["siparis_tarihi"].dt.month
df["siparis_gunu"]=df["siparis_tarihi"].dt.day
df["haftanin_gunu"]=df["siparis_tarihi"].dt.day_name()
df[["siparis_yili","siparis_ayi","siparis_gunu","haftanin_gunu"]]
# Out:
#       siparis_yili  siparis_ayi  siparis_gunu haftanin_gunu
# 0             2024            1            13      Saturday
# 1             2025            3            17        Monday
# 2             2025            6             3       Tuesday
# 3             2024            8            10      Saturday
# 4             2024            8            19        Monday
# ...            ...          ...           ...           ...
# 1423          2024            6             8      Saturday
# 1424          2025           11             6      Thursday
# 1425          2025            3             7        Friday
# 1426          2025            4            19      Saturday
# 1427          2024            9            22        Sunday
#
# [1428 rows x 4 columns]

# %%
# 9.	Veri setindeki duplicate kayıt sayısını bulun.
#Duplicate kayıtları temizleyin ve temizlikten önce ve sonra veri setinin satır sayısını yazdırın.
df.shape
# Out:
# (1428, 22)

# %%
tekrarlayan_kayitlar=df[df.duplicated()]
len(tekrarlayan_kayitlar)
# Out:
# 28

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (1400, 22)

# %%
# 10.	sehir sütunundaki benzersiz değerleri inceleyin. İstanbul, istanbul, Istanbul gibi aynı anlama gelen farklı yazımları tek bir standart biçime dönüştürün.
#Temizlikten önce ve sonra benzersiz değer sayılarını karşılaştırın.
df["sehir"].unique()
# Out:
# array(['İstanbul', 'Gaziantep', 'Kayseri', 'Antalya', 'Konya', 'Ankara',
#        'Bursa', 'Trabzon', 'Adana', 'Mersin', 'Kocaeli', 'İzmir',
#        'Eskişehir', 'Samsun', nan, 'istanbul', 'ankara', 'Istanbul',
#        'gaziantep', 'Izmir'], dtype=object)

# %%
df["sehir"].nunique()
# Out:
# 19

# %%
def metin_normalizasyonu(series):

  return(
      series.astype(str)
      .str.strip()
      .str.lower()
      .str.replace("i̇","i", regex=False)
      .str.replace("ı","i", regex=False)
      .str.replace("ö","o", regex=False)
      .str.replace("ü","u", regex=False)
      .str.replace("ç","c", regex=False)
      .str.replace("ğ","g", regex=False)
      .str.replace("ş","s", regex=False)
  )

# %%
df["sehir"]=metin_normalizasyonu(df["sehir"])
df["sehir"].unique()
# Out:
# array(['istanbul', 'gaziantep', 'kayseri', 'antalya', 'konya', 'ankara',
#        'bursa', 'trabzon', 'adana', 'mersin', 'kocaeli', 'izmir',
#        'eskisehir', 'samsun', 'nan'], dtype=object)

# %%
df["sehir"].nunique()
# Out:
# 15

# %%
#11.kategori sütunundaki tutarsız değerleri inceleyin.
# Örneğin Ev Yaşam, ev yaşam, ev&yaşam gibi farklı yazımları tek biçime dönüştürün. Temizlikten sonra value_counts() çıktısını yazdırın.
df["kategori"].unique()
# Out:
# array(['Kozmetik', 'Spor', 'Kitap', 'Elektronik', 'Ofis', 'ofis',
#        'Ev ve Yaşam', 'Elektronik ', 'spor', 'kozmetık', 'ev ve yaşam',
#        'kitap', 'Kozmetik ', 'elektronik', 'Ev&Yaşam'], dtype=object)

# %%
df["kategori"]=metin_normalizasyonu(df["kategori"])
df["kategori"].unique()
# Out:
# array(['kozmetik', 'spor', 'kitap', 'elektronik', 'ofis', 'ev ve yasam',
#        'ev&yasam'], dtype=object)

# %%
kategori_duzeltme = {
    "kozmetik":"Kozmetik",
    "spor":"Spor",
    "kitap":"Kitap",
    "elektronik":"Elektronik",
    "ofis":"Ofis",
    "ev ve yasam":"Ev Yasam",
    "ev&yasam":"Ev Yasam"
}

# %%
df["kategori"]=df["kategori"].replace(kategori_duzeltme)

# %%
df["kategori"].value_counts()
# Out:
# kategori
# Kitap         253
# Elektronik    241
# Spor          235
# Ofis          230
# Kozmetik      225
# Ev Yasam      216
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['siparis_id', 'musteri_id', 'siparis_tarihi', 'sehir', 'bolge',
#        'kategori', 'urun_adi', 'adet', 'birim_fiyat', 'indirim_orani',
#        'kargo_ucreti', 'odeme_turu', 'musteri_tipi', 'teslimat_gunu',
#        'musteri_puani', 'iade_durumu', 'kar_marji_orani', 'toplam_tutar',
#        'siparis_yili', 'siparis_ayi', 'siparis_gunu', 'haftanin_gunu'],
#       dtype='object')

# %%
#12.	Aşağıdaki koşullara uyan mantıksal olarak hatalı kayıtları bulun: birim_fiyat <= 0, toplam_tutar <= 0, teslimat_gunu < 0, musteri_puani > 5.
#bu kayıtların sayısını yazdırın ve veri setinden çıkarın.
hatali_kayitlar = df[
    (df["birim_fiyat"]<=0) |
    (df["toplam_tutar"]<=0) |
    (df["teslimat_gunu"] <0) |
    (df[ "musteri_puani"] > 5) |
    (df["musteri_puani"] < 0)
 ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13498/3118401680.py in <cell line: 0>()
#       5     (df["toplam_tutar"]<=0) |
#       6     (df["teslimat_gunu"] <0) |
# ----> 7     (df[ "musteri_puani"] > 5) |
#       8     (df["musteri_puani"] < 0)
#       9  ]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# ...

# %%
df.dtypes
# Out:
# siparis_id                 object
# musteri_id                 object
# siparis_tarihi     datetime64[ns]
# sehir                      object
# bolge                      object
# kategori                   object
# urun_adi                   object
# adet                        int64
# birim_fiyat               float64
# indirim_orani              object
# kargo_ucreti              float64
# odeme_turu                 object
# musteri_tipi               object
# teslimat_gunu             float64
# musteri_puani              object
# iade_durumu                object
# kar_marji_orani           float64
# toplam_tutar              float64
# siparis_yili                int32
# siparis_ayi                 int32
# siparis_gunu                int32
# haftanin_gunu              object
# dtype: object

# %%
#müşteri puanı object olarak kalmış
df["musteri_puani"] = pd.to_numeric(df["musteri_puani"], errors="coerce")
df["musteri_puani"].dtype
# Out:
# dtype('float64')

# %%
#12.	Aşağıdaki koşullara uyan mantıksal olarak hatalı kayıtları bulun: birim_fiyat <= 0, toplam_tutar <= 0, teslimat_gunu < 0, musteri_puani > 5.
#bu kayıtların sayısını yazdırın ve veri setinden çıkarın.
hatali_kayitlar = df[
    (df["birim_fiyat"]<=0) |
    (df["toplam_tutar"]<=0) |
    (df["teslimat_gunu"] <0) |
    (df[ "musteri_puani"] > 5) |
    (df["musteri_puani"] < 0)
 ]
hatali_kayitlar
# Out:
#      siparis_id musteri_id      siparis_tarihi     sehir    bolge  kategori  \
# 609   SIP100095    MUS1165 2025-10-12 21:31:00  istanbul  Marmara  Kozmetik
# 1008  SIP101290    MUS1225 2024-01-16 21:46:00   kocaeli  Marmara  Kozmetik
#
#                 urun_adi  adet  birim_fiyat indirim_orani  ...  musteri_tipi  \
# 609              Şampuan     2       190.17           0.1  ...        Mevcut
# 1008  Yüz Temizleme Jeli     2       303.82          0.05  ...          Yeni
#
#      teslimat_gunu musteri_puani  iade_durumu  kar_marji_orani toplam_tutar  \
# 609            3.0           6.0        Hayır            0.416       342.31
# 1008           5.0           7.0         Evet            0.287       607.16
#
#       siparis_yili  siparis_ayi  siparis_gunu  haftanin_gunu
# 609           2025           10            12         Sunday
# 1008          2024            1            16        Tuesday
#
# [2 rows x 22 columns]

# %%
len(hatali_kayitlar)
# Out:
# 2

# %%
df = df[
    (df["birim_fiyat"]>0) &
    (df["toplam_tutar"]>0) &
    (df["teslimat_gunu"] >=0) &
    (df[ "musteri_puani"] <= 5) &
    (df["musteri_puani"] >= 0)
]
df.shape
# Out:
# (1314, 22)

# %%
#13.	birim_fiyat sütunu için IQR yöntemini kullanarak Q1, Q3, IQR, alt sınır ve üst sınır değerlerini hesaplayın.
#Sonra aykırı değer içeren kayıt sayısını yazdırın.
q1 = df["birim_fiyat"].quantile(0.25)
q3 = df["birim_fiyat"].quantile(0.75)
iqr= q3 - q1
birim_fiyat_alt_sinir = q1- 1.5*iqr
birim_fiyat_ust_sinir = q3 + 1.5*iqr
birim_fiyat_alt_sinir
# Out:
# np.float64(-743.4087499999999)

# %%
birim_fiyat_ust_sinir
# Out:
# np.float64(1769.88125)

# %%
birim_fiyat_aykiri_degerler = df[(df["birim_fiyat"]< birim_fiyat_alt_sinir) | (df["birim_fiyat"] > birim_fiyat_ust_sinir)]
len(birim_fiyat_aykiri_degerler)
# Out:
# 89

# %%
#14.toplam_tutar sütunu için histogram çizdirin ve box plot çizdirin. Ardından dağılım hakkında 2–3 cümlelik kısa bir yorum yazın.
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")

# %%
 plt.hist(df["toplam_tutar"], bins = 120)
 plt.title(f"{"toplam_tutar"} sütunu için histogram")
 plt.xlabel("Toplam Tutar")
 plt.ylabel("Frekans")
 plt.tight_layout()
 plt.show()

# %%
#Toplam tutar arttıkça satış da azalmış yani çoğunluğun bütçesi 0-1500 bandında.
#2500-3000 bandındaki değerler sütunun ortalamasını gereksiz yükseltiyor olabilir. Bunlara outlier diyebiliriz.
#muhtemelen alt sınır eksilerde.

# %% [markdown]
# 15.	Aşağıdaki analizleri yapın: kategori sütunu için value_counts() çıktısını yazdırın, musteri_tipi sütunu için yüzde dağılımı hesaplayın, odeme_turu sütunu için count plot çizdirin, birim_fiyat, toplam_tutar ve musteri_puani sütunlarının temel istatistiklerini çıkarın. Son olarak şu iki soruya cevap verin: Hangi kategori en yüksek ortalama toplam_tutar değerine sahip? Hangi müşteri tipi en yüksek ortalama musteri_puani değerine sahip?

# %%
df["kategori"].value_counts()
# Out:
# kategori
# Kitap         223
# Kozmetik      200
# Spor          186
# Ev Yaşam      184
# Ofis          162
# Elektronik    140
# Name: count, dtype: int64

# %%
print((df["musteri_tipi"].value_counts(normalize=True) * 100).round(2))
# Out:
# musteri_tipi
# Mevcut    50.96
# Yeni      37.35
# VIP       11.69
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="odeme_turu", order=df["odeme_turu"].value_counts().index)
plt.title("Ödeme Türü Dağılımı")
plt.xticks(rotation=45)
plt.show()

# %%
print(df[["birim_fiyat", "toplam_tutar", "musteri_puani"]].describe())
# Out:
#        birim_fiyat  toplam_tutar  musteri_puani
# count  1095.000000   1095.000000    1095.000000
# mean    436.698950    779.359014       4.282192
# std     363.625045    631.014875       0.707625
# min      93.110000     89.680000       3.000000
# 25%     192.955000    294.815000       4.000000
# 50%     262.050000    565.580000       4.000000
# 75%     583.895000   1017.895000       5.000000
# max    1742.850000   2990.840000       5.000000

# %%
kategori_ortalama = df.groupby("kategori")["toplam_tutar"].mean().sort_values(ascending=False)

print(kategori_ortalama)
print("En yüksek kategori:", kategori_ortalama.idxmax())            #Elektronik
# Out:
# kategori
# Elektronik    1520.930643
# Spor          1018.719946
# Ev Yaşam       773.562772
# Kozmetik       737.614500
# Kitap          511.549731
# Ofis           290.443704
# Name: toplam_tutar, dtype: float64
# En yüksek kategori: Elektronik

# %%
musteri_ortalama = df.groupby("musteri_tipi")["musteri_puani"].mean().sort_values(ascending=False)

print(musteri_ortalama)
print("En yüksek müşteri tipi:", musteri_ortalama.idxmax())   #mevcut
# Out:
# musteri_tipi
# Mevcut    4.304659
# Yeni      4.259169
# VIP       4.257812
# Name: musteri_puani, dtype: float64
# En yüksek müşteri tipi: Mevcut
